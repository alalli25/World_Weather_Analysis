# %%
#Import the Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hobyo
# Processing Record 4 of Set 1 | batagay
# Processing Record 5 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 6 of Set 1 | nizhniy kuranakh
# Processing Record 7 of Set 1 | sorong
# Processing Record 8 of Set 1 | grandview
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | bonavista
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | polson
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | yulara
# Processing Record 17 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | te anau
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | sola
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | aykhal
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | korla
# Processing Record 44 of Set 1 | zhaotong
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | pauini
# Processing Record 48 of Set 1 | coffs harbour
# Processing Record 49 of Set 1 | srednekolymsk
# Processing Record 50 of Set 1 | riyadh
# Processing Record 1 of Set 2 | chimbote
# Processing Record 2 of Set 2 | naze
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | hambantota
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | yerbogachen
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | grand gaube
# Processing Record 9 of Set 2 | nefteyugansk
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | gualaco
# Processing Record 13 of Set 2 | san juan tilapa
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | mezen
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | mount gambier
# Processing Record 20 of Set 2 | midland
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | porto belo
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | fort wellington
# Processing Record 26 of Set 2 | vestmannaeyjar
# Processing Record 27 of Set 2 | rolla
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | antalaha
# Processing Record 31 of Set 2 | kununurra
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | puri
# Processing Record 34 of Set 2 | straumen
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | kashi
# Processing Record 41 of Set 2 | porto velho
# Processing Record 42 of Set 2 | nishihara
# Processing Record 43 of Set 2 | ugoofaaru
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 2 | grabovo
# Processing Record 47 of Set 2 | pinega
# Processing Record 48 of Set 2 | waipawa
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | sechura
# Processing Record 2 of Set 3 | dhidhdhoo
# Processing Record 3 of Set 3 | catarama
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | miles city
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | konstantinovka
# Processing Record 8 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | coruripe
# Processing Record 12 of Set 3 | jinxiang
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | kitchener
# Processing Record 16 of Set 3 | cam ranh
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | winchester
# Processing Record 22 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 3 | delijan
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | acarau
# Processing Record 27 of Set 3 | kaihua
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | samarai
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | bystryy istok
# Processing Record 32 of Set 3 | grindavik
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | oxford
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | cape town
# Processing Record 38 of Set 3 | rafraf
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | marica
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | muisne
# Processing Record 44 of Set 3 | grimshaw
# Processing Record 45 of Set 3 | ahipara
# Processing Record 46 of Set 3 | fairbanks
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | bluff
# Processing Record 49 of Set 3 | broome
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | bulaevo
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 4 | opuwo
# Processing Record 5 of Set 4 | jacareacanga
# Processing Record 6 of Set 4 | ust-ilimsk
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | araouane
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | bayir
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | pochutla
# Processing Record 13 of Set 4 | imeni poliny osipenko
# Processing Record 14 of Set 4 | gazanjyk
# Processing Record 15 of Set 4 | waren
# Processing Record 16 of Set 4 | kemi
# Processing Record 17 of Set 4 | shingu
# Processing Record 18 of Set 4 | marrakesh
# Processing Record 19 of Set 4 | martapura
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 4 | livingston
# Processing Record 23 of Set 4 | awbari
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | bosaso
# Processing Record 26 of Set 4 | port lincoln
# Processing Record 27 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 4 | usinsk
# Processing Record 29 of Set 4 | nago
# Processing Record 30 of Set 4 | ulladulla
# Processing Record 31 of Set 4 | meulaboh
# Processing Record 32 of Set 4 | ahtopol
# Processing Record 33 of Set 4 | viedma
# Processing Record 34 of Set 4 | keti bandar
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | konstantinovskaya
# Processing Record 38 of Set 4 | khor
# Processing Record 39 of Set 4 | biloela
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | katangli
# Processing Record 42 of Set 4 | sebastian
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | capreol
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | elizabeth city
# Processing Record 50 of Set 4 | dayong
# Processing Record 1 of Set 5 | valparaiso
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | manta
# Processing Record 5 of Set 5 | tete
# Processing Record 6 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 7 of Set 5 | behshahr
# Processing Record 8 of Set 5 | labuhan
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | ixtapa
# Processing Record 11 of Set 5 | hobart
# Processing Record 12 of Set 5 | galesburg
# Processing Record 13 of Set 5 | huambo
# Processing Record 14 of Set 5 | kovur
# Processing Record 15 of Set 5 | honiara
# Processing Record 16 of Set 5 | abalak
# Processing Record 17 of Set 5 | castro
# Processing Record 18 of Set 5 | khonsa
# Processing Record 19 of Set 5 | belyy yar
# Processing Record 20 of Set 5 | scottsbluff
# Processing Record 21 of Set 5 | abu kamal
# Processing Record 22 of Set 5 | kundiawa
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | krasnoarmeysk
# Processing Record 26 of Set 5 | lubango
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | bilma
# Processing Record 29 of Set 5 | troitskoye
# Processing Record 30 of Set 5 | nuuk
# Processing Record 31 of Set 5 | ust-maya
# Processing Record 32 of Set 5 | najran
# Processing Record 33 of Set 5 | omboue
# Processing Record 34 of Set 5 | san patricio
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | senneterre
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | pingliang
# Processing Record 39 of Set 5 | moron
# Processing Record 40 of Set 5 | angoche
# Processing Record 41 of Set 5 | porto walter
# Processing Record 42 of Set 5 | kochubey
# Processing Record 43 of Set 5 | pevek
# Processing Record 44 of Set 5 | alihe
# Processing Record 45 of Set 5 | ribeira grande
# Processing Record 46 of Set 5 | port-gentil
# Processing Record 47 of Set 5 | lakes entrance
# Processing Record 48 of Set 5 | kruisfontein
# Processing Record 49 of Set 5 | skowhegan
# Processing Record 50 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 6 | coahuayana
# Processing Record 2 of Set 6 | huilong
# Processing Record 3 of Set 6 | jilin
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | makaryev
# Processing Record 6 of Set 6 | sham churasi
# Processing Record 7 of Set 6 | half moon bay
# Processing Record 8 of Set 6 | constitucion
# Processing Record 9 of Set 6 | hovd
# Processing Record 10 of Set 6 | labranzagrande
# Processing Record 11 of Set 6 | cayenne
# Processing Record 12 of Set 6 | natal
# Processing Record 13 of Set 6 | kahului
# Processing Record 14 of Set 6 | buenaventura
# Processing Record 15 of Set 6 | benghazi
# Processing Record 16 of Set 6 | pacific grove
# Processing Record 17 of Set 6 | nisia floresta
# Processing Record 18 of Set 6 | davila
# Processing Record 19 of Set 6 | turukhansk
# Processing Record 20 of Set 6 | ushtobe
# Processing Record 21 of Set 6 | rocha
# Processing Record 22 of Set 6 | les cayes
# Processing Record 23 of Set 6 | coihaique
# Processing Record 24 of Set 6 | nedjo
# Processing Record 25 of Set 6 | honningsvag
# Processing Record 26 of Set 6 | russell
# Processing Record 27 of Set 6 | adeje
# Processing Record 28 of Set 6 | isla mujeres
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | flin flon
# Processing Record 31 of Set 6 | santa cruz
# Processing Record 32 of Set 6 | monrovia
# Processing Record 33 of Set 6 | iisalmi
# Processing Record 34 of Set 6 | luanda
# Processing Record 35 of Set 6 | sale
# Processing Record 36 of Set 6 | kaeo
# Processing Record 37 of Set 6 | naousa
# Processing Record 38 of Set 6 | oktyabrskoye
# Processing Record 39 of Set 6 | bambous virieux
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | kalianget
# Processing Record 42 of Set 6 | jieshi
# Processing Record 43 of Set 6 | glyadyanskoye
# Processing Record 44 of Set 6 | sabang
# Processing Record 45 of Set 6 | huarmey
# Processing Record 46 of Set 6 | brownfield
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | duldurga
# Processing Record 49 of Set 6 | waihi beach
# Processing Record 50 of Set 6 | gualaquiza
# Processing Record 1 of Set 7 | aksha
# Processing Record 2 of Set 7 | bintulu
# Processing Record 3 of Set 7 | kamina
# Processing Record 4 of Set 7 | caraquet
# Processing Record 5 of Set 7 | zeya
# Processing Record 6 of Set 7 | margate
# Processing Record 7 of Set 7 | dali
# Processing Record 8 of Set 7 | neosho
# Processing Record 9 of Set 7 | sanchor
# Processing Record 10 of Set 7 | zanjan
# Processing Record 11 of Set 7 | xinzhou
# Processing Record 12 of Set 7 | sinsheim
# Processing Record 13 of Set 7 | yozgat
# Processing Record 14 of Set 7 | chicama
# Processing Record 15 of Set 7 | port blair
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | belize
# Processing Record 18 of Set 7 | airai
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | irbeyskoye
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | krasnokholmskiy
# Processing Record 23 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 7 | baruun-urt
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | nagaur
# Processing Record 27 of Set 7 | cairns
# Processing Record 28 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 7 | sakaraha
# Processing Record 30 of Set 7 | caravelas
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | pitkyaranta
# Processing Record 34 of Set 7 | lahat
# Processing Record 35 of Set 7 | deqing
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | raudeberg
# Processing Record 38 of Set 7 | myitkyina
# Processing Record 39 of Set 7 | tupik
# Processing Record 40 of Set 7 | qasigiannguit
# Processing Record 41 of Set 7 | ozinki
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 | acapulco
# Processing Record 44 of Set 7 | ukiah
# Processing Record 45 of Set 7 | chirongui
# Processing Record 46 of Set 7 | monte patria
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | puerto escondido
# Processing Record 49 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 50 of Set 7 | harper
# Processing Record 1 of Set 8 | makakilo city
# Processing Record 2 of Set 8 | ajjampur
# Processing Record 3 of Set 8 | komsomolskiy
# Processing Record 4 of Set 8 | chhukha
# City not found. Skipping...
# Processing Record 5 of Set 8 | porto novo
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | beyneu
# Processing Record 8 of Set 8 | gizo
# Processing Record 9 of Set 8 | cidreira
# Processing Record 10 of Set 8 | goya
# Processing Record 11 of Set 8 | karratha
# Processing Record 12 of Set 8 | bartica
# Processing Record 13 of Set 8 | sembe
# Processing Record 14 of Set 8 | champerico
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 8 | santa cruz del sur
# Processing Record 18 of Set 8 | jiuquan
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | paungde
# Processing Record 21 of Set 8 | luderitz
# Processing Record 22 of Set 8 | geraldton
# Processing Record 23 of Set 8 | vila praia de ancora
# Processing Record 24 of Set 8 | esil
# Processing Record 25 of Set 8 | stornoway
# Processing Record 26 of Set 8 | siderno
# Processing Record 27 of Set 8 | lalmohan
# Processing Record 28 of Set 8 | zyryanka
# Processing Record 29 of Set 8 | nelson bay
# Processing Record 30 of Set 8 | aswan
# Processing Record 31 of Set 8 | shache
# Processing Record 32 of Set 8 | kirakira
# Processing Record 33 of Set 8 | atasu
# Processing Record 34 of Set 8 | ulaangom
# Processing Record 35 of Set 8 | deputatskiy
# Processing Record 36 of Set 8 | marzuq
# Processing Record 37 of Set 8 | seddon
# Processing Record 38 of Set 8 | dembi dolo
# Processing Record 39 of Set 8 | cabinda
# Processing Record 40 of Set 8 | palaikastron
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 8 | katha
# City not found. Skipping...
# Processing Record 44 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | lufilufi
# Processing Record 46 of Set 8 | ebeltoft
# Processing Record 47 of Set 8 | berlevag
# Processing Record 48 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 8 | chaumont
# Processing Record 50 of Set 8 | lazaro cardenas
# Processing Record 1 of Set 9 | itoman
# Processing Record 2 of Set 9 | tsiroanomandidy
# Processing Record 3 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 4 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | lodja
# Processing Record 9 of Set 9 | carbonia
# Processing Record 10 of Set 9 | arroyo
# Processing Record 11 of Set 9 | parrita
# Processing Record 12 of Set 9 | ha tinh
# Processing Record 13 of Set 9 | belmonte
# Processing Record 14 of Set 9 | inyonga
# Processing Record 15 of Set 9 | muros
# Processing Record 16 of Set 9 | mercedes
# Processing Record 17 of Set 9 | paciran
# Processing Record 18 of Set 9 | panguma
# Processing Record 19 of Set 9 | oranjemund
# Processing Record 20 of Set 9 | bara
# Processing Record 21 of Set 9 | mulege
# Processing Record 22 of Set 9 | kalach-na-donu
# Processing Record 23 of Set 9 | brownsville
# Processing Record 24 of Set 9 | la palma
# Processing Record 25 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 9 | porosozero
# Processing Record 27 of Set 9 | bud
# Processing Record 28 of Set 9 | bethanien
# Processing Record 29 of Set 9 | mashivka
# Processing Record 30 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | araguaina
# Processing Record 32 of Set 9 | tatishchevo
# Processing Record 33 of Set 9 | maniitsoq
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | shimoda
# Processing Record 36 of Set 9 | mapiri
# Processing Record 37 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 9 | kieta
# Processing Record 39 of Set 9 | liberty
# Processing Record 40 of Set 9 | kuloy
# Processing Record 41 of Set 9 | saurimo
# Processing Record 42 of Set 9 | dzaoudzi
# Processing Record 43 of Set 9 | umm lajj
# Processing Record 44 of Set 9 | tual
# Processing Record 45 of Set 9 | palenque
# Processing Record 46 of Set 9 | itaituba
# Processing Record 47 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 9 | sinjar
# Processing Record 49 of Set 9 | sao felix do xingu
# Processing Record 50 of Set 9 | bubaque
# Processing Record 1 of Set 10 | brae
# Processing Record 2 of Set 10 | itarema
# Processing Record 3 of Set 10 | mahajanga
# Processing Record 4 of Set 10 | kurri kurri
# Processing Record 5 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 10 | tukrah
# Processing Record 7 of Set 10 | anloga
# Processing Record 8 of Set 10 | inuvik
# Processing Record 9 of Set 10 | linhares
# Processing Record 10 of Set 10 | ambulu
# Processing Record 11 of Set 10 | sitka
# Processing Record 12 of Set 10 | fasa
# Processing Record 13 of Set 10 | smirnykh
# Processing Record 14 of Set 10 | marienburg
# Processing Record 15 of Set 10 | qui nhon
# Processing Record 16 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 10 | cockburn town
# Processing Record 18 of Set 10 | yecuatla
# Processing Record 19 of Set 10 | pombia
# Processing Record 20 of Set 10 | cheremukhovo
# Processing Record 21 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 10 | phan thiet
# Processing Record 23 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 10 | sambava
# Processing Record 25 of Set 10 | liverpool
# Processing Record 26 of Set 10 | zapolyarnyy
# Processing Record 27 of Set 10 | poya
# Processing Record 28 of Set 10 | keuruu
# Processing Record 29 of Set 10 | hire
# City not found. Skipping...
# Processing Record 30 of Set 10 | iqaluit
# Processing Record 31 of Set 10 | san rafael
# Processing Record 32 of Set 10 | ust-uda
# Processing Record 33 of Set 10 | sisimiut
# Processing Record 34 of Set 10 | saint marys
# Processing Record 35 of Set 10 | perene
# Processing Record 36 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 10 | gastonia
# Processing Record 38 of Set 10 | tapejara
# Processing Record 39 of Set 10 | sorland
# Processing Record 40 of Set 10 | zirgan
# Processing Record 41 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 10 | aldan
# Processing Record 43 of Set 10 | bantogon
# Processing Record 44 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 10 | ruiz
# Processing Record 46 of Set 10 | kudahuvadhoo
# Processing Record 47 of Set 10 | ancud
# Processing Record 48 of Set 10 | himora
# City not found. Skipping...
# Processing Record 49 of Set 10 | westport
# Processing Record 50 of Set 10 | mount isa
# Processing Record 1 of Set 11 | lahad datu
# Processing Record 2 of Set 11 | atagay
# Processing Record 3 of Set 11 | saint-louis
# Processing Record 4 of Set 11 | jasper
# Processing Record 5 of Set 11 | loandjili
# Processing Record 6 of Set 11 | kaya
# Processing Record 7 of Set 11 | chapais
# Processing Record 8 of Set 11 | batesville
# Processing Record 9 of Set 11 | vardo
# Processing Record 10 of Set 11 | novoilinsk
# Processing Record 11 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | tucuman
# Processing Record 14 of Set 11 | pafos
# Processing Record 15 of Set 11 | wicklow
# Processing Record 16 of Set 11 | qena
# Processing Record 17 of Set 11 | avera
# Processing Record 18 of Set 11 | erenhot
# Processing Record 19 of Set 11 | juneau
# Processing Record 20 of Set 11 | gigmoto
# Processing Record 21 of Set 11 | riviere-au-renard
# Processing Record 22 of Set 11 | phuket
# Processing Record 23 of Set 11 | celestun
# Processing Record 24 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 11 | constantine
# Processing Record 26 of Set 11 | clifton springs
# Processing Record 27 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 11 | iwaki
# Processing Record 29 of Set 11 | isangel
# Processing Record 30 of Set 11 | secunda
# Processing Record 31 of Set 11 | domoni
# Processing Record 32 of Set 11 | durham
# Processing Record 33 of Set 11 | saryg-sep
# Processing Record 34 of Set 11 | hengyang
# Processing Record 35 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 11 | dukat
# Processing Record 37 of Set 11 | ngunguru
# Processing Record 38 of Set 11 | henties bay
# Processing Record 39 of Set 11 | gao
# Processing Record 40 of Set 11 | taber
# Processing Record 41 of Set 11 | wagga wagga
# Processing Record 42 of Set 11 | denia
# Processing Record 43 of Set 11 | casimiro castillo
# Processing Record 44 of Set 11 | kodinsk
# Processing Record 45 of Set 11 | wanning
# Processing Record 46 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 11 | masterton
# Processing Record 49 of Set 11 | tubuala
# Processing Record 50 of Set 11 | sibu
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | ejido
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | kuching
# Processing Record 5 of Set 12 | dudinka
# Processing Record 6 of Set 12 | zhezkazgan
# Processing Record 7 of Set 12 | saint-georges
# Processing Record 8 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 9 of Set 12 | biskamzha
# Processing Record 10 of Set 12 | road town
# Processing Record 11 of Set 12 | takhtamygda
# Processing Record 12 of Set 12 | banda aceh
# Processing Record 13 of Set 12 | quanzhou
# Processing Record 14 of Set 12 | mazatlan
# Processing Record 15 of Set 12 | tabat
# Processing Record 16 of Set 12 | yongan
# Processing Record 17 of Set 12 | na wa
# Processing Record 18 of Set 12 | camacha
# Processing Record 19 of Set 12 | chitral
# Processing Record 20 of Set 12 | mustasaari
# Processing Record 21 of Set 12 | kisangani
# Processing Record 22 of Set 12 | broken hill
# Processing Record 23 of Set 12 | bonfim
# Processing Record 24 of Set 12 | campbell river
# Processing Record 25 of Set 12 | tilichiki
# Processing Record 26 of Set 12 | mehamn
# Processing Record 27 of Set 12 | kirando
# Processing Record 28 of Set 12 | pangnirtung
# Processing Record 29 of Set 12 | kamra
# Processing Record 30 of Set 12 | barcelos
# Processing Record 31 of Set 12 | brainerd
# Processing Record 32 of Set 12 | goldap
# Processing Record 33 of Set 12 | el silencio
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | mushie
# Processing Record 36 of Set 12 | alyangula
# Processing Record 37 of Set 12 | polunochnoye
# Processing Record 38 of Set 12 | comodoro rivadavia
# Processing Record 39 of Set 12 | faya
# Processing Record 40 of Set 12 | kiboga
# Processing Record 41 of Set 12 | punta alta
# Processing Record 42 of Set 12 | quatre cocos
# Processing Record 43 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 12 | menongue
# Processing Record 45 of Set 12 | zakupne
# Processing Record 46 of Set 12 | baytown
# Processing Record 47 of Set 12 | huai thalaeng
# Processing Record 48 of Set 12 | lancaster
# Processing Record 49 of Set 12 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | ewa beach
# Processing Record 1 of Set 13 | sterling
# Processing Record 2 of Set 13 | yining
# Processing Record 3 of Set 13 | sao joao da barra
# Processing Record 4 of Set 13 | surt
# Processing Record 5 of Set 13 | kalispell
# Processing Record 6 of Set 13 | keffi
# Processing Record 7 of Set 13 | riberalta
# Processing Record 8 of Set 13 | markova
# Processing Record 9 of Set 13 | pathein
# Processing Record 10 of Set 13 | vestmanna
# Processing Record 11 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 13 | kardailovo
# Processing Record 13 of Set 13 | chak jhumra
# Processing Record 14 of Set 13 | prata
# Processing Record 15 of Set 13 | okha
# Processing Record 16 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 13 | katobu
# Processing Record 19 of Set 13 | nara
# Processing Record 20 of Set 13 | tatarsk
# Processing Record 21 of Set 13 | teguldet
# Processing Record 22 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 13 | alofi
# Processing Record 24 of Set 13 | washington
# Processing Record 25 of Set 13 | umtata
# Processing Record 26 of Set 13 | soyo
# Processing Record 27 of Set 13 | norwich
# Processing Record 28 of Set 13 | gisborne
# Processing Record 29 of Set 13 | bama
# Processing Record 30 of Set 13 | devils lake
# Processing Record 31 of Set 13 | ucluelet
# Processing Record 32 of Set 13 | eyl
# Processing Record 33 of Set 13 | kiruna
# Processing Record 34 of Set 13 | parana
# Processing Record 35 of Set 13 | yarada
# Processing Record 36 of Set 13 | talara
# Processing Record 37 of Set 13 | knyaze-volkonskoye
# Processing Record 38 of Set 13 | pilar
# Processing Record 39 of Set 13 | ornskoldsvik
# Processing Record 40 of Set 13 | madang
# Processing Record 41 of Set 13 | champoton
# Processing Record 42 of Set 13 | khash
# Processing Record 43 of Set 13 | strezhevoy
# Processing Record 44 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 13 | eureka
# Processing Record 46 of Set 13 | clyde river
# Processing Record 47 of Set 13 | zambezi
# Processing Record 48 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 49 of Set 13 | buraydah
# Processing Record 50 of Set 13 | mumford
# Processing Record 1 of Set 14 | agucadoura
# Processing Record 2 of Set 14 | rovenki
# Processing Record 3 of Set 14 | mitsamiouli
# Processing Record 4 of Set 14 | ternate
# Processing Record 5 of Set 14 | olinda
# Processing Record 6 of Set 14 | prince rupert
# Processing Record 7 of Set 14 | safaga
# Processing Record 8 of Set 14 | linxia
# Processing Record 9 of Set 14 | mkushi
# Processing Record 10 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 11 of Set 14 | tiznit
# Processing Record 12 of Set 14 | saint-joseph
# Processing Record 13 of Set 14 | san borja
# Processing Record 14 of Set 14 | arari
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | aspindza
# Processing Record 17 of Set 14 | kez
# Processing Record 18 of Set 14 | forestville
# Processing Record 19 of Set 14 | nowy targ
# Processing Record 20 of Set 14 | vilhena
# Processing Record 21 of Set 14 | makueni
# Processing Record 22 of Set 14 | zhicheng
# Processing Record 23 of Set 14 | byron bay
# Processing Record 24 of Set 14 | havre-saint-pierre
# Processing Record 25 of Set 14 | charters towers
# Processing Record 26 of Set 14 | ruteng
# Processing Record 27 of Set 14 | kuressaare
# Processing Record 28 of Set 14 | sanguem
# Processing Record 29 of Set 14 | edirne
# Processing Record 30 of Set 14 | hit
# Processing Record 31 of Set 14 | makinsk
# Processing Record 32 of Set 14 | neiafu
# Processing Record 33 of Set 14 | scarborough
# Processing Record 34 of Set 14 | ginda
# Processing Record 35 of Set 14 | careiro da varzea
# Processing Record 36 of Set 14 | ouadda
# Processing Record 37 of Set 14 | pueblo nuevo
# Processing Record 38 of Set 14 | xuanwu
# Processing Record 39 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 14 | jishou
# Processing Record 41 of Set 14 | kontagora
# Processing Record 42 of Set 14 | beloha
# Processing Record 43 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 14 | kenora
# Processing Record 45 of Set 14 | yeppoon
# Processing Record 46 of Set 14 | odweyne
# Processing Record 47 of Set 14 | ketchikan
# Processing Record 48 of Set 14 | cotija
# City not found. Skipping...
# Processing Record 49 of Set 14 | mobai
# Processing Record 50 of Set 14 | baykit
# Processing Record 1 of Set 15 | pascagoula
# Processing Record 2 of Set 15 | praia
# Processing Record 3 of Set 15 | solikamsk
# Processing Record 4 of Set 15 | seymchan
# Processing Record 5 of Set 15 | lasem
# Processing Record 6 of Set 15 | yinchuan
# Processing Record 7 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 15 | idenao
# Processing Record 9 of Set 15 | muncar
# Processing Record 10 of Set 15 | lisakovsk
# Processing Record 11 of Set 15 | auka
# Processing Record 12 of Set 15 | tabas
# Processing Record 13 of Set 15 | turki
# Processing Record 14 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 15 | rachitoasa
# Processing Record 16 of Set 15 | la rioja
# Processing Record 17 of Set 15 | jinchang
# Processing Record 18 of Set 15 | tabou
# Processing Record 19 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 15 | masca
# Processing Record 21 of Set 15 | khilok
# Processing Record 22 of Set 15 | trebisacce
# Processing Record 23 of Set 15 | kholodnyy
# Processing Record 24 of Set 15 | dagana
# Processing Record 25 of Set 15 | labytnangi
# Processing Record 26 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 27 of Set 15 | mareeba
# Processing Record 28 of Set 15 | sakakah
# Processing Record 29 of Set 15 | bima
# Processing Record 30 of Set 15 | dingle
# Processing Record 31 of Set 15 | nanakuli
# Processing Record 32 of Set 15 | kaili
# Processing Record 33 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 15 | auki
# Processing Record 35 of Set 15 | severo-yeniseyskiy
# Processing Record 36 of Set 15 | guerrero
# Processing Record 37 of Set 15 | gamba
# Processing Record 38 of Set 15 | voroshnevo
# Processing Record 39 of Set 15 | college
# Processing Record 40 of Set 15 | naberera
# Processing Record 41 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 15 | bajah
# Processing Record 43 of Set 15 | sobolevo
# Processing Record 44 of Set 15 | mirador
# Processing Record 45 of Set 15 | ilinskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#check how many cities there are (should be more than 500)
print(len(city_data))
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Provideniya  64.38 -173.30     50.00        81          90
# 1           Rikitea -23.12 -134.97     70.09        84          79
# 2             Hobyo   5.35   48.53     75.97        77          60
# 3           Batagay  67.63  134.63     34.12        93          57
# 4  Nizhniy Kuranakh  58.84  125.49     39.52        78           0
# 5            Sorong  -0.88  131.25     77.25        87          81
# 6         Grandview  38.89  -94.53     95.00        38           1
# 7            Avarua -21.21 -159.78     75.20        73           0
# 8      Puerto Ayora  -0.74  -90.35     77.00        57          59
# 9         Bonavista  48.65  -53.11     62.01        83          32
#
#    Wind Speed Country                 Date Current Description
# 0        2.24      RU  2020-08-23 20:08:22     overcast clouds
# 1       22.08      PF  2020-08-23 20:03:58       broken clouds
# 2       24.00      SO  2020-08-23 20:05:00       broken clouds
# 3        3.60      RU  2020-08-23 20:08:23       broken clouds
# 4        1.48      RU  2020-08-23 20:08:23           clear sky
# 5        7.40      ID  2020-08-23 20:08:23       broken clouds
# 6        9.17      US  2020-08-23 20:08:23           clear sky
# 7       11.41      CK  2020-08-23 20:04:49           clear sky
# 8       21.92      EC  2020-08-23 20:03:54       broken clouds
# 9        1.99      CA  2020-08-23 20:06:04    scattered clouds

# %%
# Reorder the columns
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

#print re-ordered database
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# 0       Provideniya      RU  2020-08-23 20:08:22  64.38 -173.30     50.00
# 1           Rikitea      PF  2020-08-23 20:03:58 -23.12 -134.97     70.09
# 2             Hobyo      SO  2020-08-23 20:05:00   5.35   48.53     75.97
# 3           Batagay      RU  2020-08-23 20:08:23  67.63  134.63     34.12
# 4  Nizhniy Kuranakh      RU  2020-08-23 20:08:23  58.84  125.49     39.52
# 5            Sorong      ID  2020-08-23 20:08:23  -0.88  131.25     77.25
# 6         Grandview      US  2020-08-23 20:08:23  38.89  -94.53     95.00
# 7            Avarua      CK  2020-08-23 20:04:49 -21.21 -159.78     75.20
# 8      Puerto Ayora      EC  2020-08-23 20:03:54  -0.74  -90.35     77.00
# 9         Bonavista      CA  2020-08-23 20:06:04  48.65  -53.11     62.01
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        81          90        2.24     overcast clouds
# 1        84          79       22.08       broken clouds
# 2        77          60       24.00       broken clouds
# 3        93          57        3.60       broken clouds
# 4        78           0        1.48           clear sky
# 5        87          81        7.40       broken clouds
# 6        38           1        9.17           clear sky
# 7        73           0       11.41           clear sky
# 8        57          59       21.92       broken clouds
# 9        83          32        1.99    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
